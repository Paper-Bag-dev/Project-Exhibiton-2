# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("School Tap connection under Jal Jeevan Mission.csv")
df = pd.read_csv("jjm.csv")
data.head(20)
# Out:
#         state_name district_name  block_name     panchayat_name village_name  \
# 0   Andhra Pradesh        Kadapa  Veeraballi  Sangamvandlapalli   Peddiveedu
# 1   Andhra Pradesh        Kadapa  Veeraballi              Matli        Matli
# 2   Andhra Pradesh        Kadapa  Veeraballi    Thatiguntapalli        Matli
# 3   Andhra Pradesh        Kadapa  Veeraballi  Gurrappagaripalli   Veeraballi
# 4   Andhra Pradesh        Kadapa  Veeraballi              Matli        Matli
# 5   Andhra Pradesh        Kadapa  Veeraballi           Gadikota     Gadikota
# 6   Andhra Pradesh        Kadapa  Veeraballi         Vongimalla   Vongimalla
# 7   Andhra Pradesh        Kadapa  Veeraballi         Vongimalla   Vongimalla
# 8   Andhra Pradesh        Kadapa  Veeraballi         Vongimalla   Vongimalla
# 9   Andhra Pradesh        Kadapa  Veeraballi         Vongimalla   Vongimalla
# 10  Andhra Pradesh        Kadapa  Veeraballi         Veeraballi   Veeraballi
# ...

# %% [markdown]
# ## Data Cleaning
# here we clean the data and remove the empty entries

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state_name          80 non-null     object
#  1   district_name       80 non-null     object
#  2   block_name          80 non-null     object
#  3   panchayat_name      80 non-null     object
#  4   village_name        80 non-null     object
#  5   habitation_name     80 non-null     object
#  6   habitation_id       80 non-null     int64
#  7   school_id           80 non-null     int64
#  8   school_name         80 non-null     object
#  9   no_of_student       80 non-null     int64
#  10  school_category     80 non-null     object
#  11  school_subcategory  80 non-null     object
#  12  update_date         80 non-null     object
# dtypes: int64(3), object(10)
# memory usage: 8.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 25 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   State                                                                                  259 non-null    object
#  1   State_UT_Code                                                                          259 non-null    float64
#  2   Financial  Year                                                                        259 non-null    object
#  3   Opening Balance                                                                        223 non-null    float64
#  4   Funds Allocated by Government of India                                                 223 non-null    float64
# ...

# %%
df.head(10)
# Out:
#                State  State_UT_Code Financial  Year  Opening Balance   \
# 0     Andhra Pradesh            1.0         2015-16             33.44
# 1  Arunachal Pradesh            2.0         2015-16             16.09
# 2              Assam            3.0         2015-16             92.10
# 3              Bihar            4.0         2015-16            276.54
# 4       Chhattisgarh            5.0         2015-16             12.05
# 5                Goa            6.0         2015-16              3.73
# 6            Gujarat            7.0         2015-16             48.38
# 7            Haryana            8.0         2015-16             57.32
# 8   Himachal Pradesh            9.0         2015-16             45.69
# 9          Jharkhand           10.0         2015-16             88.10
#
#    Funds Allocated by Government of India  \
# 0                                  156.69
# 1                                   58.08
# 2                                  268.26
# ...

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
i = 13
while i <= 23:
    df.drop(f"Unnamed: {i}",axis=1, inplace=True)
    i += 1

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
df.dropna(inplace=True)
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
df.head(10)
# Out:
#                State  State_UT_Code Financial  Year  Opening Balance   \
# 0     Andhra Pradesh            1.0         2015-16             33.44
# 1  Arunachal Pradesh            2.0         2015-16             16.09
# 2              Assam            3.0         2015-16             92.10
# 3              Bihar            4.0         2015-16            276.54
# 4       Chhattisgarh            5.0         2015-16             12.05
# 5                Goa            6.0         2015-16              3.73
# 6            Gujarat            7.0         2015-16             48.38
# 7            Haryana            8.0         2015-16             57.32
# 8   Himachal Pradesh            9.0         2015-16             45.69
# 9          Jharkhand           10.0         2015-16             88.10
#
#    Funds Allocated by Government of India  \
# 0                                  156.69
# 1                                   58.08
# 2                                  268.26
# ...

# %%
df.head(31)
# Out:
#                 State  State_UT_Code Financial  Year  Opening Balance   \
# 0      Andhra Pradesh            1.0         2015-16             33.44
# 1   Arunachal Pradesh            2.0         2015-16             16.09
# 2               Assam            3.0         2015-16             92.10
# 3               Bihar            4.0         2015-16            276.54
# 4        Chhattisgarh            5.0         2015-16             12.05
# 5                 Goa            6.0         2015-16              3.73
# 6             Gujarat            7.0         2015-16             48.38
# 7             Haryana            8.0         2015-16             57.32
# 8    Himachal Pradesh            9.0         2015-16             45.69
# 9           Jharkhand           10.0         2015-16             88.10
# 10          Karnataka           11.0         2015-16            156.80
# 11             Kerala           12.0         2015-16             18.10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223 entries, 0 to 258
# Data columns (total 13 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   State                                                                                  223 non-null    object
#  1   State_UT_Code                                                                          223 non-null    float64
#  2   Financial  Year                                                                        223 non-null    object
#  3   Opening Balance                                                                        223 non-null    float64
#  4   Funds Allocated by Government of India                                                 223 non-null    float64
# ...

# %%
df1 = pd.DataFrame(df)

df1.drop(df1.index[37 : 223], inplace=True)

# %%
df1.head(40)
# Out:
#                 State  State_UT_Code Financial  Year  Opening Balance   \
# 0      Andhra Pradesh            1.0         2015-16             33.44
# 1   Arunachal Pradesh            2.0         2015-16             16.09
# 2               Assam            3.0         2015-16             92.10
# 3               Bihar            4.0         2015-16            276.54
# 4        Chhattisgarh            5.0         2015-16             12.05
# 5                 Goa            6.0         2015-16              3.73
# 6             Gujarat            7.0         2015-16             48.38
# 7             Haryana            8.0         2015-16             57.32
# 8    Himachal Pradesh            9.0         2015-16             45.69
# 9           Jharkhand           10.0         2015-16             88.10
# 10          Karnataka           11.0         2015-16            156.80
# 11             Kerala           12.0         2015-16             18.10
# ...

# %%
df1.plot(x="State", y=["Funds Allocated by Government of India", "Expenditure out of Government of India's Share"], kind="bar", figsize=(10, 12))
# Out:
# <AxesSubplot: xlabel='State'>

# %%
sns.jointplot(x="Total Funds Available (Government of India's Share)", y= "Expenditure out of Government of India's Share", data= df1, kind= 'scatter')

# %% [markdown]
# ## Andhra Pradesh
# Block : Veeraballi

# %%
Cat_of_Schools= sns.countplot(data=data, x="school_subcategory")
Cat_of_Schools.set_xticklabels(Cat_of_Schools.get_xticklabels(), rotation=40, ha="right")
# Out:
# [Text(0, 0, 'Primary only with grades 1 to 5'),
#  Text(1, 0, 'Secondary/Sr. Sec. with grades 1 to 10'),
#  Text(2, 0, 'Upper Primary with grades 1 to 8')]

# %%
Types_of_School = sns.barplot(data=data, x="school_name", y="no_of_student")
Types_of_School.set_xticklabels(Types_of_School.get_xticklabels(), rotation=40, ha="right")
# Out:
# [Text(0, 0, 'MPPS'),
#  Text(1, 0, 'ZPHS'),
#  Text(2, 0, 'MPPS (U)'),
#  Text(3, 0, 'MPPS(U)'),
#  Text(4, 0, 'MPUPS'),
#  Text(5, 0, 'MPPS (T)'),
#  Text(6, 0, 'MPP (U)'),
#  Text(7, 0, 'MPUP'),
#  Text(8, 0, 'MPUPS (U)'),
#  Text(9, 0, 'Z.P.H.S')]

# %%
data["school_category"].value_counts()
# Out:
# Local Body    63
# Govt.         17
# Name: school_category, dtype: int64
